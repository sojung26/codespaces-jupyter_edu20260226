# %% [markdown]
# # 멀티에이전트 크롤링 파이프라인 구축
# 앞선 실습에서 우리는 두 가지 전문 에이전트를 설계했습니다.
# - **Navigator** (02): 브라우저를 조작하여 웹사이트 구조를 분석하고 CSS 셀렉터를 찾아내는 탐색 전문가
# - **Coder** (03): Blueprint를 받아 실제로 동작하는 크롤링 코드를 작성하고 스스로 디버깅하는 개발 전문가
#
# 이번 실습에서는 이 두 에이전트를 **멀티에이전트 워크플로우** 위에서 함께 작업하도록 구현합니다.
#
# Navigator와 Coder는 각자의 역할에만 집중하고, 두 에이전트 사이에는 **Blueprint(청사진)** 라는 구조화된 JSON 객체가 오갑니다. Blueprint에는 수집할 URL, 계층별 CSS 셀렉터, 페이지네이션 방식, JS 렌더링 여부 등이 담겨 있어, Coder는 HTML을 직접 보지 않고도 정확한 크롤링 코드를 작성할 수 있습니다.

# %% [markdown]
# 👤 사용자: "이 사이트에서 데이터 수집해줘" ↓ 🗺️ Navigator ──(Blueprint)──▶ 💻 Coder ──▶ 📄 수집 결과
#
#
# ### 이번 실습에서 배우는 것
#
# 1. **동적 N계층 Blueprint 스키마** 설계 — 1~N개의 탐색 계층을 유연하게 표현하는 Pydantic 모델
# 2. **Navigator 에이전트 고도화** — `get_page_structure` (HTML 구조 분석) + `browse_web` (동적 인터랙션) 이중 도구 체계
# 3. **Coder 에이전트 구현** — Blueprint 해석 → Playwright 코드 작성 → 실행 → 오류 시 셀프 디버깅
# 4. **파이프라인 연결** — Navigator → Coder 전체 흐름 자동화
# 5. **실습 과제** — LangGraph `StateGraph`로 파이프라인을 더욱 견고하게 구조화

# %%
import os, sys
from dotenv import load_dotenv

load_dotenv(override=True)

# PROJECT_ROOT를 .env에서 읽기 (없으면 현재 디렉토리)
project_root = os.getenv("PROJECT_ROOT", os.getcwd())

# 프로젝트 루트가 유효하지 않으면, 현재 위치에서 상위로 찾기
if not os.path.exists(os.path.join(project_root, "app")):
    # 상위 디렉토리 탐색
    current = os.getcwd()
    for _ in range(5):
        if os.path.exists(os.path.join(current, "app")):
            project_root = current
            break
        current = os.path.dirname(current)

# Working Directory 설정
os.chdir(project_root)
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import app

print(f"✅ Project Root: {project_root}")
print(f"✅ Working Directory: {os.getcwd()}")
# Out:
# ✅ Project Root: /workspaces/codespaces-jupyter/AAWS_project
# ✅ Working Directory: /workspaces/codespaces-jupyter/AAWS_project

# %%
import asyncio
from browser_use import Agent, Browser, ChatGoogle

import nest_asyncio

# 주피터 노트북 환경에서 비동기 루프 중복 실행 오류를 방지하기 위해 사용합니다.
nest_asyncio.apply()

# 가상 디스플레이(noVNC) 번호를 지정합니다.
# 이 설정이 있어야 GUI 브라우저가 가상 화면(:1)에 나타납니다.
os.environ["DISPLAY"] = ":1"
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.4.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.2) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # 동적 N계층 Blueprint 스키마 설계
#
# 핵심 아이디어: **"계층을 레고 블록처럼, 필요한 만큼만 쌓는다"**
#
# ---
#
# ## 클래스 구조
#
# NavigatorBlueprintCollection ← Navigator의 최종 출력 (1개 이상의 Blueprint 묶음)
#
# └── blueprints: list[NavigatorBlueprint]
#
# └── layers: list[PageLayer] ← 탐색 계층 하나를 표현하는 단위 블록
#
#
#
# ##### `PageLayer` - 탐색 계층 단위 블록
#
# | 필드 | 설명 |
# |------|------|
# | `layer_name` | 이 계층의 역할 이름 (예: '기사 목록', '상품 상세') |
# | `url_pattern` | 이 계층의 URL 구조 예시 |
# | `selectors` | `{필드명: CSS셀렉터}` 딕셔너리 |
# | `navigate_to_next` | 다음 계층 링크의 CSS 셀렉터. **마지막 계층이면 반드시 `None`** |
# | `pagination_method` | 페이지네이션 방식 (URL파라미터 / AJAX버튼 / 무한스크롤 / `None`) |
#
# **`navigate_to_next` 필드가 핵심입니다:**
# - 값이 있으면 → 그 CSS 셀렉터로 링크를 추출하여 다음 계층으로 이동
# - `None`이면 → 이 계층이 마지막 (데이터 수집 완료)
#
# ##### `NavigatorBlueprint` - 단일 수집 작업 설계도
#
# | 필드 | 설명 |
# |------|------|
# | `entry_urls` | 크롤링 시작 URL 목록. 구조가 같고 시작점만 다른 경우 여러 개 지정 |
# | `total_layers` | 탐색에 필요한 총 계층 수 (layers 리스트 길이와 동일) |
# | `layers` | 탐색 순서대로 정렬된 `PageLayer` 목록 |
# | `rendering_type` | `"Static SSR"` 또는 `"Dynamic CSR/JS"` |
# | `anti_bot_notes` | 로그인, 팝업, 캡차 등 주의사항. 없으면 `"없음"` |
#
# ##### `NavigatorBlueprintCollection` - Navigator의 최종 출력
#
# | 필드 | 설명 |
# |------|------|
# | `total_jobs` | 총 Blueprint 수 |
# | `blueprints` | Blueprint 목록 |
#
# **Blueprint 개수 결정 기준:**
# - 구조(계층/셀렉터)가 같고 시작 URL만 다른 경우 → **Blueprint 1개**, `entry_urls`에 복수 URL
# - 구조가 근본적으로 다른 경우 (다른 사이트 등) → **Blueprint 별도 생성**
#
# ---
#
# ## 스키마 검증 예시 3가지
#
# | 예시 | 설명 |
# |------|------|
# | 예시 1 | Blueprint 1개, `entry_urls` 1개 (단일 섹션) |
# | 예시 2 | Blueprint 1개, `entry_urls` 2개 (구조 동일, URL만 다름) |
# | 예시 3 | Blueprint 2개 (사이트 구조가 달라 분리) |

# %%
import json
from typing import Optional
from pydantic import BaseModel, Field, field_validator

# ==========================================
# 동적 N계층 Blueprint 스키마
# ==========================================

class PageLayer(BaseModel):
    """하나의 탐색 계층을 표현하는 단위 블록"""
    layer_name: str = Field(
        description="이 계층의 역할 이름 (예: '기사 목록', '상품 상세')"
    )
    url_pattern: str = Field(
        description="이 계층의 URL 구조 예시 또는 진입점 URL (실제 시작 URL은 entry_urls 참조)"
    )
    selectors: dict[str, str] = Field(
        description="이 계층에서 수집할 데이터의 CSS 셀렉터 딕셔너리 (key: 필드명, value: CSS 셀렉터)"
    )
    navigate_to_next: Optional[str] = Field(
        default=None,
        description="다음 계층으로 이동하는 링크의 CSS 셀렉터. 마지막 계층이면 반드시 None."
    )
    pagination_method: Optional[str] = Field(
        default=None,
        description="페이지네이션 방식 (URL파라미터 / AJAX버튼 / 무한스크롤 / None)"
    )

    @field_validator("selectors", mode="before")
    @classmethod
    def parse_selectors(cls, v):
        if isinstance(v, str):
            try:
                return json.loads(v)
            except Exception:
                pass
        return v

    # ↓ 이 validator 추가
    @field_validator("navigate_to_next", "pagination_method", mode="before")
    @classmethod
    def parse_none_string(cls, v):
        """LLM이 None을 문자열 "None"으로 반환하는 경우를 처리합니다."""
        if v in ("None", "null", "없음", "N/A", ""):
            return None
        return v

class NavigatorBlueprint(BaseModel):
    """Navigator가 Coder에게 전달하는 동적 N계층 크롤링 설계 도면 (단일 구조)"""
    entry_urls: list[str] = Field(
        description=(
            "크롤링을 시작할 URL 목록. "
            "구조(계층/셀렉터)가 동일하고 시작점만 다른 경우 여러 개 지정. "
            "예) 정치 섹션 URL + 사회 섹션 URL"
        )
    )
    total_layers: int = Field(
        description="탐색에 필요한 총 계층 수 (layers 리스트의 길이와 동일)"
    )
    layers: list[PageLayer] = Field(
        description="탐색 순서대로 정렬된 PageLayer 목록. layers[0]은 entry_urls 각각에 반복 적용됨."
    )
    rendering_type: str = Field(
        description="Static SSR 또는 Dynamic CSR/JS"
    )
    anti_bot_notes: str = Field(
        description="로그인 필요 여부, 팝업, 캡차, 우회 조언 등. 없으면 '없음'"
    )


class NavigatorBlueprintCollection(BaseModel):
    """Navigator가 반환하는 Blueprint 모음 (1개 이상)"""
    total_jobs: int = Field(
        description="총 Blueprint 수. 구조가 같으면 1개, 구조가 다른 사이트/섹션은 각각 1개."
    )
    blueprints: list[NavigatorBlueprint] = Field(
        description=(
            "수집 작업별 Blueprint 목록. "
            "- 구조 동일 + 시작 URL만 다름 → Blueprint 1개, entry_urls에 복수 URL "
            "- 구조가 근본적으로 다름 → Blueprint를 별도 생성하여 복수 반환"
        )
    )


# ==========================================
# ✅ 스키마 검증 예시
# ==========================================

# 예시 1: 단일 섹션 (네이버 금융 주식 시세) - Blueprint 1개, entry_urls 1개
sample_single = NavigatorBlueprintCollection(
    total_jobs=1,
    blueprints=[
        NavigatorBlueprint(
            entry_urls=["https://finance.naver.com/sise/sise_rise.nhn"],
            total_layers=1,
            layers=[
                PageLayer(
                    layer_name="주식 상승 종목 테이블",
                    url_pattern="https://finance.naver.com/sise/sise_rise.nhn",
                    selectors={"stock_name": "td.col_type1 a", "change_rate": "td.rate_t"},
                    navigate_to_next=None,
                    pagination_method="URL파라미터"
                )
            ],
            rendering_type="Static SSR",
            anti_bot_notes="없음"
        )
    ]
)

# 예시 2: 동일 구조, 출발 URL만 다른 경우 (정치면 + 사회면) - Blueprint 1개, entry_urls 2개
sample_multi_url = NavigatorBlueprintCollection(
    total_jobs=1,
    blueprints=[
        NavigatorBlueprint(
            entry_urls=[
                "https://news.naver.com/section/100",  # 정치
                "https://news.naver.com/section/102",  # 사회
            ],
            total_layers=2,
            layers=[
                PageLayer(
                    layer_name="뉴스 목록",
                    url_pattern="https://news.naver.com/section/{sid}",
                    selectors={"article_link": "a.sa_text_title"},
                    navigate_to_next="a.sa_text_title",
                    pagination_method="AJAX버튼"
                ),
                PageLayer(
                    layer_name="기사 상세",
                    url_pattern="https://n.news.naver.com/mnews/article/{mid}/{aid}",
                    selectors={"title": "h2.media_end_head_headline", "body": "#dic_area", "datetime": ".media_end_head_info_dateline"},
                    navigate_to_next=None
                )
            ],
            rendering_type="Dynamic CSR/JS",
            anti_bot_notes="더보기 버튼 AJAX 방식"
        )
    ]
)

# 예시 3: 구조가 다른 두 사이트 - Blueprint 2개
sample_multi_blueprint = NavigatorBlueprintCollection(
    total_jobs=2,
    blueprints=[
        NavigatorBlueprint(
            entry_urls=["https://news.naver.com/section/100"],
            total_layers=2,
            layers=[
                PageLayer(layer_name="뉴스 목록", url_pattern="https://news.naver.com/section/100",
                          selectors={"article_link": "a.sa_text_title"}, navigate_to_next="a.sa_text_title"),
                PageLayer(layer_name="기사 상세", url_pattern="https://n.news.naver.com/mnews/article/{mid}/{aid}",
                          selectors={"title": "h2.media_end_head_headline", "body": "#dic_area"}, navigate_to_next=None)
            ],
            rendering_type="Dynamic CSR/JS", anti_bot_notes="없음"
        ),
        NavigatorBlueprint(
            entry_urls=["https://www.danawa.com/product/?cateCode=112758"],
            total_layers=2,
            layers=[
                PageLayer(layer_name="상품 목록", url_pattern="https://www.danawa.com/product/?cateCode=112758",
                          selectors={"product_link": "a.prod_name"}, navigate_to_next="a.prod_name", pagination_method="URL파라미터"),
                PageLayer(layer_name="상품 상세", url_pattern="https://prod.danawa.com/info/?pcode={id}",
                          selectors={"name": "h3.prod_tit", "price": "span.low_price", "specs": "div.spec_list"}, navigate_to_next=None)
            ],
            rendering_type="Dynamic CSR/JS", anti_bot_notes="없음"
        )
    ]
)

# %%
print("✅ 예시 1 (단일):")
print(sample_single.model_dump_json(indent=2))
print("\n✅ 예시 2 (동일 구조, URL 2개):")
print(sample_multi_url.model_dump_json(indent=2))
print("\n✅ 예시 3 (다른 구조 사이트 2개):")
print(sample_multi_blueprint.model_dump_json(indent=2))
# Out:
# ✅ 예시 1 (단일):
# {
#   "total_jobs": 1,
#   "blueprints": [
#     {
#       "entry_urls": [
#         "https://finance.naver.com/sise/sise_rise.nhn"
#       ],
#       "total_layers": 1,
#       "layers": [
#         {
#           "layer_name": "주식 상승 종목 테이블",
#           "url_pattern": "https://finance.naver.com/sise/sise_rise.nhn",
#           "selectors": {
#             "stock_name": "td.col_type1 a",
#             "change_rate": "td.rate_t"
#           },
#           "navigate_to_next": null,
#           "pagination_method": "URL파라미터"
#         }
#       ],
#       "rendering_type": "Static SSR",
#       "anti_bot_notes": "없음"
#     }
#   ]
# }
#
# ✅ 예시 2 (동일 구조, URL 2개):
# {
#   "total_jobs": 1,
#   "blueprints": [
#     {
#       "entry_urls": [
#         "https://news.naver.com/section/100",
#         "https://news.naver.com/section/102"
#       ],
#       "total_layers": 2,
#       "layers": [
#         {
#           "layer_name": "뉴스 목록",
#           "url_pattern": "https://news.naver.com/section/{sid}",
#           "selectors": {
#             "article_link": "a.sa_text_title"
#           },
#           "navigate_to_next": "a.sa_text_title",
#           "pagination_method": "AJAX버튼"
#         },
#         {
#           "layer_name": "기사 상세",
#           "url_pattern": "https://n.news.naver.com/mnews/article/{mid}/{aid}",
#           "selectors": {
#             "title": "h2.media_end_head_headline",
#             "body": "#dic_area",
#             "datetime": ".media_end_head_info_dateline"
#           },
#           "navigate_to_next": null,
#           "pagination_method": null
#         }
#       ],
#       "rendering_type": "Dynamic CSR/JS",
#       "anti_bot_notes": "더보기 버튼 AJAX 방식"
#     }
#   ]
# }
#
# ✅ 예시 3 (다른 구조 사이트 2개):
# {
#   "total_jobs": 2,
#   "blueprints": [
#     {
#       "entry_urls": [
#         "https://news.naver.com/section/100"
#       ],
#       "total_layers": 2,
#       "layers": [
#         {
#           "layer_name": "뉴스 목록",
#           "url_pattern": "https://news.naver.com/section/100",
#           "selectors": {
#             "article_link": "a.sa_text_title"
#           },
#           "navigate_to_next": "a.sa_text_title",
#           "pagination_method": null
#         },
#         {
#           "layer_name": "기사 상세",
#           "url_pattern": "https://n.news.naver.com/mnews/article/{mid}/{aid}",
#           "selectors": {
#             "title": "h2.media_end_head_headline",
#             "body": "#dic_area"
#           },
#           "navigate_to_next": null,
#           "pagination_method": null
#         }
#       ],
#       "rendering_type": "Dynamic CSR/JS",
#       "anti_bot_notes": "없음"
#     },
#     {
#       "entry_urls": [
#         "https://www.danawa.com/product/?cateCode=112758"
#       ],
#       "total_layers": 2,
#       "layers": [
#         {
#           "layer_name": "상품 목록",
#           "url_pattern": "https://www.danawa.com/product/?cateCode=112758",
#           "selectors": {
#             "product_link": "a.prod_name"
#           },
#           "navigate_to_next": "a.prod_name",
#           "pagination_method": "URL파라미터"
#         },
#         {
#           "layer_name": "상품 상세",
#           "url_pattern": "https://prod.danawa.com/info/?pcode={id}",
#           "selectors": {
#             "name": "h3.prod_tit",
#             "price": "span.low_price",
#             "specs": "div.spec_list"
#           },
#           "navigate_to_next": null,
#           "pagination_method": null
#         }
#       ],
#       "rendering_type": "Dynamic CSR/JS",
#       "anti_bot_notes": "없음"
#     }
#   ]
# }

# %% [markdown]
# # Navigator 에이전트 재설계

# %% [markdown]
# 왜 `get_page_structure` + `browse_web`를 함께 사용하는가?
#
# 웹 데이터를 수집할 때 가장 어려운 문제는
# **"어디에서 데이터를 가져와야 하는지(구조 이해)"** 와
# **"실제로 데이터를 가져오는 것(행동 실행)"** 이 서로 다른 문제라는 점입니다.
#
# 우리는 이 두 문제를 하나의 도구로 해결하지 않고,
# **서로 역할이 다른 두 개의 도구로 분리**하여 해결합니다.
#
# ---
#
# ## 1️⃣ get_page_structure — 구조 분석 도구 (Planning Tool)
#
# `get_page_structure`는 웹페이지의 **HTML 구조 일부를 토큰 효율적으로 반환**합니다.
#
# 이 도구의 목적은 **데이터 수집 계획(청사진)을 만드는 것**입니다.
#
# ### 역할
# - 페이지의 HTML 구조 확인
# - class / id 패턴 분석
# - 반복되는 데이터 영역 발견 (뉴스 목록, 상품 리스트 등)
# - 안정적인 CSS selector 설계
#
# 즉,
# > "어디에서 데이터를 가져와야 하는가?"를 이해하는 단계입니다.
#
# ⚠️ 중요한 점:
# - browser agent는 화면 의미를 이해하지만
# - **재사용 가능한 CSS selector 설계에는 HTML 근거가 필요**합니다.
#
# `get_page_structure`는 바로 이 근거를 제공합니다.
#
# ---
#
# ## 2️⃣ browse_web — 실행 도구 (Execution Tool)
#
# `browse_web`는 browser-use 기반 에이전트를 이용해 실제 브라우저 행동을 수행합니다.
#
# ### 역할
# - 클릭
# - 스크롤
# - 페이지 이동
# - 동적 콘텐츠 로딩
# - 실제 데이터 확인
#
# 즉,
# > "계획한 위치에서 실제로 데이터를 가져오는 단계"입니다.
#
# browser-use는 사람처럼 페이지를 이해하고 행동하는 데 강하지만,
# 기본적으로 **셀렉터 추출기(selector extractor)가 아니라 실행기(executor)** 입니다.
#
# ---

# %%
import json
from dataclasses import dataclass
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy
from langgraph.checkpoint.memory import InMemorySaver
from browser_use import Agent, Browser, ChatGoogle
from crawl4ai import AsyncWebCrawler


# ==========================================
# 공유 브라우저 (세션 유지)
# ==========================================
shared_browser = Browser(
    headless=False,
    disable_security=True,
    keep_alive=True,
)


# ==========================================
# NavigatorContext - 빈 컨텍스트 유지 (확장 대비)
# ==========================================
@dataclass
class NavigatorContext:
    pass  # 미래 확장용 (예: 로그인 정보, 프록시 설정 등)


# ==========================================
# 도구 1: get_page_structure
# crawl4ai로 HTML 구조 샘플을 토큰 효율적으로 반환
# CSS 셀렉터 탐색에 최적화
# ==========================================
@tool(parse_docstring=True)
async def get_page_structure(url: str, scraping_goal: str) -> str:
    """웹페이지 HTML을 내부 LLM이 직접 분석하여 CSS 셀렉터 결과만 반환합니다.
    Navigator는 HTML 원문을 볼 필요 없이 셀렉터 분석 결과만 받습니다.

    Args:
        url: 분석할 웹페이지 URL
        scraping_goal: 수집하려는 데이터 설명. 예) "기사 제목과 링크 URL", "상품명과 가격"
    """
    from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode
    from langchain.chat_models import init_chat_model
    from langchain_core.messages import HumanMessage
    import re

    print(f"\n📐 [get_page_structure] {url}")
    print(f"   🎯 분석 목표: {scraping_goal}")

    # ── Step 1: crawl4ai로 JS 렌더링된 HTML 수집 ──
    browser_cfg = BrowserConfig(headless=True, java_script_enabled=True)
    run_cfg = CrawlerRunConfig(
        cache_mode=CacheMode.BYPASS,
        page_timeout=15000,
        wait_for="css:main a[href]",      # 1차: '의미 있는 링크'가 등장하면 트리거
        delay_before_return_html=1.0,     # 2차: 추가 1초 대기 (JS 렌더링 완료 버퍼)
        wait_for_images=False,
    )

    try:
        async with AsyncWebCrawler(config=browser_cfg) as crawler:
            result = await crawler.arun(url=url, config=run_cfg)
    except Exception as e:
        return f"[Error] HTML 수집 실패: {e}\n→ browse_web을 사용하세요."

    # cleaned_html: class/id 보존, 광고 제거
    # 내부 LLM이 읽으므로 Navigator에게 줄 때보다 넉넉하게
    cleaned_html = (result.cleaned_html or "")[:8000]

    if not cleaned_html.strip():
        return "[Warning] HTML이 비어 있습니다. JS 렌더링 실패 가능성.\n→ browse_web을 사용하세요."

    # ── Step 2: 내부 LLM이 HTML 분석 → 셀렉터만 추출 ──
    analysis_llm = init_chat_model("google_genai:gemini-flash-latest", temperature=0)

    analysis_prompt = f"""아래 HTML에서 "{scraping_goal}"에 해당하는 요소의 CSS 셀렉터를 찾고 JSON으로만 응답하세요.
    [분석할 HTML]
    {cleaned_html}
    [응답 형식 - JSON만, 다른 텍스트 없이]
    {{
    "selectors": {{
        "필드명": "CSS셀렉터"
    }},
    "samples": {{
        "필드명": ["실제 텍스트 예시 1", "실제 텍스트 예시 2", "실제 텍스트 예시 3"]
    }},
    "container": "목록 전체를 감싸는 컨테이너 셀렉터 (없으면 null)",
    "navigate_to_next": "다음 계층(상세 페이지)으로 이동하는 링크 셀렉터 (없으면 null)",
    "pagination": "페이지네이션 방식 (URL파라미터/AJAX버튼/무한스크롤/null)",
    "confidence": "high 또는 medium 또는 low",
    "note": "주의사항. 확인된 경우 '없음'"
    }}
    [셀렉터 작성 규칙]
    - tag + class/id 조합 필수: a.sa_text_title, div.article_box, #main_content
    - a, div, span 처럼 태그만 있는 셀렉터 절대 금지
    - HTML에 실제로 존재하는 class/id만 사용
    - 없는 값은 반드시 null로 표기하세요. 문자열 "None"은 사용 금지.
    - 텍스트와 URL을 모두 수집해야 하면 키를 분리하세요:
        예) "title": "a.sa_text_title"  (텍스트 추출용)
            "url":   "a.sa_text_title"  (href 추출용, 같은 셀렉터여도 키는 분리)
    - samples에는 HTML에서 실제로 찾은 텍스트를 기재하세요
    - confidence low면 note에 근거 명시
    """
    response = await analysis_llm.ainvoke([HumanMessage(analysis_prompt)])
    raw = response.content.strip()

    # 마크다운 코드블록 제거 (```json ... ``` 대응)
    json_match = re.search(r'\{.*\}', raw, re.DOTALL)
    if json_match:
        try:
            parsed = json.loads(json_match.group())
            print(f"   ✅ 셀렉터 추출: {parsed.get('selectors')} / confidence={parsed.get('confidence')}")
            return json.dumps(parsed, ensure_ascii=False, indent=2)
        except json.JSONDecodeError:
            pass

    # JSON 파싱 실패 시 원문 반환
    print(f"   ⚠️ JSON 파싱 실패, 원문 반환")
    return raw


# ==========================================
# 도구 2: browse_web
# 동적 인터랙션이 필요할 때만 사용 (클릭, 스크롤 등)
# 토큰 비용이 크므로 get_page_structure로 해결 안 될 때만 호출
# ==========================================
@tool(parse_docstring=True)
async def browse_web(url: str, instruction: str) -> str:
    """실제 브라우저로 웹페이지를 방문하여 동적 인터랙션을 수행합니다.
    
    사용 시점:
    - 클릭, 스크롤, 검색어 입력, 로그인 등 인터랙션이 필요한 경우
    - get_page_structure가 "[Warning]" 또는 "[Error]"를 반환한 경우 (폴백)
    - 현재 페이지에서 이어서 대화형으로 작업하는 경우
    
    Args:
        url: 이동할 URL. 현재 페이지에서 이어서 작업하려면 빈 문자열("")을 전달하세요.
        instruction: 수행할 구체적인 작업. 원하는 결과물을 명확히 기술하세요.
                     예) "검색창에 '무선 마우스'를 입력하고 결과 목록의 상위 3개 상품명을 반환하세요"
                     예) "4번째 상품의 이름과 가격을 알려주세요"
                     예) "기사 목록의 CSS 셀렉터를 찾아주세요 (get_page_structure 폴백)"
    """
    print(f"\n🌐 [browse_web] {'→ ' + url if url else '현재 페이지 이어서'}")
    print(f"   📋 작업: {instruction}")
    bu_llm = ChatGoogle(model="gemini-flash-latest")
    # url 유무에 따라 분기
    if url:
        nav_prefix = (
            f"첫 번째 액션으로 반드시 navigate를 실행하여 아래 URL로 이동하세요.\n"
            f"현재 브라우저 상태와 관계없이 즉시 이동부터 시작합니다.\n\n"
            f"[이동할 URL]\n{url}\n\n"
            f"[이동 후 수행할 작업]"
        )
    else:
        nav_prefix = (
            f"현재 열려있는 페이지에서 바로 아래 작업을 수행하세요.\n"
            f"navigate 액션으로 다른 페이지로 이동하지 마세요.\n\n"
            f"[수행할 작업]"
        )
    task = f"""{nav_prefix}
    {instruction}
    [결과 보고 규칙]
    - 작업 결과를 구체적으로 보고하세요.
    - 요소를 find_elements로 찾기 어렵다면, screenshot으로 화면을 직접 확인한 뒤
    시각적으로 목표 요소를 파악하세요.
    - CSS 셀렉터가 필요한 작업이라면:
        tag + class/id 조합으로 작성하세요. 예) "a.sa_text_title", "#dic_area"
        "a", "div" 처럼 태그만 있는 셀렉터는 사용 금지.
    - 확인 불가능한 정보는 "확인 불가"로 명시하세요.
    - 작업 완료 후 현재 페이지 URL과 상태를 함께 보고하세요.
    """
    agent = Agent(task=task, llm=bu_llm, use_vision="auto", browser=shared_browser)
    history = await agent.run(max_steps=15)
    result = history.final_result() or "탐색 완료, 결과 반환 없음"
    print(f"\n✅ [browse_web 완료] {result[:200]}...")
    return result

# %%
# ==========================================
# Navigator 에이전트
# ==========================================
nav_model = init_chat_model("google_genai:gemini-flash-latest", temperature=0.1)
nav_checkpointer = InMemorySaver()

NAVIGATOR_SYSTEM_PROMPT = """
당신은 웹 크롤링 파이프라인의 총괄 설계자 'Navigator'입니다.
도구를 상황에 맞게 판단하여 사용하고,
최종적으로 Coder가 즉시 실행할 수 있는 안정적인 크롤링 Blueprint를 설계합니다.

당신의 역할은 도구를 기계적으로 실행하는 것이 아니라,
웹 구조를 이해하고 데이터 수집 전략(청사진)을 설계하는 것입니다.

────────────────
[도구 역할]

■ browse_web(url, instruction)
탐색, 인터랙션, 그리고 검증(Validation)을 위한 도구입니다.

다음 상황에서 사용하세요:
- 원하는 데이터가 존재하는 URL을 파악해야 할 때
- 클릭, 검색 입력, 스크롤 등 실제 조작이 필요할 때
- JS 렌더링 이후 콘텐츠 확인이 필요할 때
- get_page_structure의 samples만으로 검증이 불충분할 때

url이 ""이면 현재 페이지에서 작업을 이어갑니다.

---

■ get_page_structure(url, scraping_goal)
데이터 추출을 위한 CSS 셀렉터 구조를 분석합니다.

사용 조건:
- 데이터가 존재하는 URL이 확정된 이후 호출합니다.
- HTML 구조 기반 selector 후보를 생성하는 단계입니다.
- 반환 JSON의 selectors를 그대로 Blueprint에 사용합니다.

반환 형식:
{
  "selectors": {"필드명": "CSS셀렉터"},
  "samples":   {"필드명": ["실제 텍스트 예시1", "예시2", "예시3"]},
  "container": "컨테이너 셀렉터",
  "navigate_to_next": "다음 계층 링크 셀렉터",
  "pagination": "페이지네이션 방식",
  "confidence": "high/medium/low",
  "note": "주의사항"
}

samples를 먼저 확인하여 셀렉터가 올바른 요소를 가리키는지 1차 검증하세요.
※ 당신은 HTML 원문을 직접 보지 않습니다.

────────────────
[핵심 설계 원칙]

1. browse_web는 "탐색 도구"이면서 동시에 "검증 도구"입니다.
2. get_page_structure는 구조(structure)를 찾고,
   samples로 1차 검증 → 부족하면 browse_web으로 2차 검증합니다.
3. 항상 가장 효율적인 도구를 판단하여 선택하세요.
   (항상 먼저 사용해야 하는 도구는 없습니다.)

────────────────
[작업 흐름]

1. 지시를 받으면 수집 목표와 초기 URL을 파악합니다.

2. 목표 URL 상태 판단:
   - 데이터 위치가 명확 → get_page_structure 호출
   - 위치가 불명확 → browse_web으로 탐색

3. get_page_structure 결과 분석:
   - confidence = high/medium
        → samples를 확인합니다.
          samples가 수집 목표와 일치 → Blueprint 후보로 채택
          samples가 불명확       → browse_web으로 실제 화면과 대조 검증
   - confidence = low 또는 Warning/Error
        → browse_web으로 구조 재확인 후 재분석

4. 상세 페이지가 존재하면:
   navigate_to_next 링크 중 하나를 샘플로 선택하여
   get_page_structure를 재호출합니다.

5. 구조와 의미가 모두 확인되면 Blueprint를 완성합니다.

────────────────
[Blueprint 작성 규칙]

- get_page_structure JSON의 selectors를 그대로 사용합니다.
- navigate_to_next가 있으면 layers[i].navigate_to_next에 기록합니다.
- 구조가 동일하고 entry URL만 다른 경우 Blueprint를 통합합니다.
- 구조가 근본적으로 다르면 Blueprint를 분리합니다.

────────────────
[중요 행동 규칙]

- selector는 반드시 실제 데이터 요소와 대응되어야 합니다.
- 숨겨진 요소, 광고 영역, 템플릿 영역 선택을 피하세요.
- 검증 순서: samples 확인(무료) → browse_web 검증(비용 발생) 순으로 진행하세요.
"""


navigator_agent = create_agent(
    model=nav_model,
    system_prompt=NAVIGATOR_SYSTEM_PROMPT,
    context_schema=NavigatorContext,   # 빈 컨텍스트 유지 (확장 대비)
    tools=[get_page_structure, browse_web],
    checkpointer=nav_checkpointer,
    response_format=ToolStrategy(NavigatorBlueprintCollection),
)

print("✅ Navigator 에이전트 준비 완료")
print("   - 도구 1: get_page_structure (crawl4ai, 토큰 효율적)")
print("   - 도구 2: browse_web (browser-use, 인터랙션 전용)")
print("   - 출력: NavigatorBlueprintCollection")
# Out:
# ✅ Navigator 에이전트 준비 완료
#    - 도구 1: get_page_structure (crawl4ai, 토큰 효율적)
#    - 도구 2: browse_web (browser-use, 인터랙션 전용)
#    - 출력: NavigatorBlueprintCollection

# %% [markdown]
# ### 네비게이터 테스트

# %%
import json, os

ARTIFACT_DIR = os.path.join(project_root, "code_artifacts")
os.makedirs(ARTIFACT_DIR, exist_ok=True)

def save_blueprints(collection: NavigatorBlueprintCollection, prefix: str):
    """NavigatorBlueprintCollection을 Blueprint 개수만큼 별도 파일로 저장"""
    saved_paths = []
    for i, bp in enumerate(collection.blueprints):
        filename = f"blueprint_{prefix}_{i+1}.json"
        filepath = os.path.join(ARTIFACT_DIR, filename)
        with open(filepath, "w", encoding="utf-8") as f:
            json.dump(bp.model_dump(), f, ensure_ascii=False, indent=2)
        saved_paths.append(filepath)
        print(f"  💾 저장 완료: {filepath}")
    return saved_paths

print(f"✅ 유틸리티 준비 완료. 아티팩트 경로: {ARTIFACT_DIR}")
# Out:
# ✅ 유틸리티 준비 완료. 아티팩트 경로: /workspaces/codespaces-jupyter/AAWS_project/code_artifacts

# %%
from langchain_core.messages import HumanMessage

# ──────────────────────────────────────────────────────
# 테스트 (1): 정치 섹션 기사 제목 5개 수집
# ──────────────────────────────────────────────────────
print("=" * 60)
print("🧪 테스트 (1): 정치 섹션 기사 제목 5개 수집")
print("=" * 60)

nav_config_1 = {"configurable": {"thread_id": "nav_test_1"}}
nav_context_1 = NavigatorContext()  # 빈 컨텍스트

response_1 = await navigator_agent.ainvoke(
    {"messages": [HumanMessage(
        "https://news.naver.com에서 정치 섹션의"
        "최신 기사 제목 5개와 각 기사 URL을 수집하는 Blueprint를 작성해주세요. "
        "탐색은 이 URL에서 시작하세요."
    )]},
    config=nav_config_1,
    context=nav_context_1,
)

collection_1: NavigatorBlueprintCollection = response_1["structured_response"]

print(f"\n✅ 결과: {collection_1.total_jobs}개 Blueprint 생성")
for i, bp in enumerate(collection_1.blueprints):
    print(f"\n  [Blueprint {i+1}]")
    print(f"    entry_urls : {bp.entry_urls}")
    print(f"    계층 수    : {bp.total_layers}")
    for j, layer in enumerate(bp.layers):
        print(f"    Layer {j+1}   : {layer.layer_name} | selectors={layer.selectors}")

print("\n📁 파일 저장:")
paths_1 = save_blueprints(collection_1, prefix="test1")
# Out:
# ============================================================
# 🧪 테스트 (1): 정치 섹션 기사 제목 5개 수집
# ============================================================
# INFO     [service] Using anonymized telemetry, see https://docs.browser-use.com/development/monitoring/telemetry.
# 🌐 [browse_web] → https://news.naver.com
#    📋 작업: '정치' 섹션 메뉴의 URL을 찾아서 알려주세요.
# INFO     [Agent] 🎯 Task: 첫 번째 액션으로 반드시 navigate를 실행하여 아래 URL로 이동하세요.
# 현재 브라우저 상태와 관계없이 즉시 이동부터 시작합니다.
#
# [이동할 URL]
# https://news.naver.com
#
# [이동 후 수행할 작업]
#     '정치' 섹션 메뉴의 URL을 찾아서 알려주세요.
#     [결과 보고 규칙]
#     - 작업 결과를 구체적으로 보고하세요.
#     - 요소를 find_elements로 찾기 어렵다면, screenshot으로 화면을 직접 확인한 뒤
#     시각적으로 목표 요소를 파악하세요.
#     - CSS 셀렉터가 필요한 작업이라면:
#         tag + class/id 조합으로 작성하세요. 예) "a.sa_text_title", "#dic_area"
#         "a", "div" 처럼 태그만 있는 셀렉터는 사용 금지.
#     - 확인 불가능한 정보는 "확인 불가"로 명시하세요.
#     - 작업 완료 후 현재 페이지 URL과 상태를 함께 보고하세요.
#
# INFO     [Agent] 📦 Newer version available: 0.12.0 (current: 0.11.13). Upgrade with: uv add browser-use==0.12.0
# INFO     [Agent] Starting a browser-use agent with version 0.11.13, with provider=google and model=gemini-flash-latest
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 0 | ▶️ 2 | ✅ 0 ➡️ 31 👂) handler browser_use.browser.watchdog_base.BrowserSession.on_BrowserStartEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.BrowserSession.on_BrowserStartEvent(?▶ BrowserStartEvent#256c 🏃)
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 0 | ▶️ 2 | ✅ 0 ➡️ 31 👂) handler browser_use.browser.watchdog_base.LocalBrowserWatchdog.on_BrowserLaunchEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.LocalBrowserWatchdog.on_BrowserLaunchEvent(?▶ BrowserLaunchEvent#8a92 🏃)
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 1:
# INFO     [Agent]   ❔ Eval: Agent initialized. No previous action to evaluate.
# INFO     [Agent]   🧠 Memory: Starting the task by navigating to Naver News as requested.
# INFO     [Agent]   🎯 Next goal: Navigate to https://news.naver.com
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 2:
# INFO     [Agent]   👍 Eval: The navigation to https://news.naver.com was successful but the page content returned an 'Access Denied' error. Verdict: Failure (due to server-side blocking).
# INFO     [Agent]   🧠 Memory: Attempted to access Naver News directly but encountered an Access Denied error. Switching strategy to use a search engine to find the '정치' section URL.
# INFO     [Agent]   🎯 Next goal: Search for the Naver News Politics section URL on DuckDuckGo.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 정치 섹션 URL, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 정치 섹션 URL'
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 3:
# INFO     [Agent]   👍 Eval: The search for the Naver News Politics section URL on DuckDuckGo was successful, providing several potential leads. Verdict: Success
# INFO     [Agent]   🧠 Memory: Encountered Access Denied on news.naver.com. Searched DuckDuckGo for the Politics section URL. Found a promising blog post and several references to the URL structure.
# INFO     [Agent]   🎯 Next goal: Attempt to navigate to Naver News again and take a screenshot to verify the state, then try to find the '정치' section link.
# INFO     [Agent]   ▶️  [1/2] write_file: file_name: todo.md, content: # Naver News Politics Section URL Task
#
# - [ ] Navigate to Naver News and handle access issues
# - [ ] Locate the '정치' section menu element
# - [ ] Extract..., append: False, trailing_newline: True, leading_newline: True
# INFO     [tools] 💾 Data written to file todo.md successfully. File location: /tmp/browser_use_agent_069a110a-eba2-7444-8000-2d871e3b3a9f_1772163246/browseruse_agent_data/todo.md
# INFO     [Agent]   ▶️  [2/2] navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 4:
# INFO     [Agent]   ⚠️ Eval: The navigation to https://news.naver.com resulted in an 'Access Denied' error, making the page content inaccessible. Verdict: Failure (Server-side block).
# INFO     [Agent]   🧠 Memory: Navigated to news.naver.com twice and received 'Access Denied' both times. Current URL is https://news.naver.com/. Switching to mobile site (m.news.naver.com) to attempt access.
# INFO     [Agent]   🎯 Next goal: Navigate to the mobile version of Naver News to bypass the access block and find the '정치' section URL.
# INFO     [Agent]   ▶️   navigate: url: https://m.news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://m.news.naver.com
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 5:
# INFO     [Agent]   ⚠️ Eval: The navigation to the mobile site (m.news.naver.com) also resulted in an Access Denied error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct access to news.naver.com and m.news.naver.com is blocked by the server. I need to find the Politics section URL through search results since I cannot interact with the site's navigation menu.
# INFO     [Agent]   🎯 Next goal: Search for the exact URL of the Naver News Politics section to provide the requested information.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 정치 섹션 URL, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 정치 섹션 URL'
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 6:
# INFO     [Agent]   👍 Eval: The search for the Naver News Politics section URL on DuckDuckGo was successful in finding references, though direct access to the site remains blocked. Verdict: Success (Search-wise).
# INFO     [Agent]   🧠 Memory: I have tried navigating to news.naver.com and m.news.naver.com but both were blocked. I have search results from DuckDuckGo that might contain the URL. I am now retrying the mandatory navigation to the main news page as per the user's specific instruction.
# INFO     [Agent]   🎯 Next goal: Navigate to Naver News as requested and verify if the access block persists.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 7:
# INFO     [Agent]   👍 Eval: The navigation to https://news.naver.com was successful but resulted in an 'Access Denied' error, preventing interaction with the menu. Verdict: Failure (Access Blocked)
# INFO     [Agent]   🧠 Memory: Naver News is blocking direct access with a 403 error. I have tried both desktop and mobile URLs. I need to find the '정치' section URL via external search since the internal menu is inaccessible.
# INFO     [Agent]   🎯 Next goal: Search for the exact '정치' section URL on DuckDuckGo and try to verify it by direct navigation.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 정치 섹션 URL, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 정치 섹션 URL'
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 8:
# INFO     [Agent]   👍 Eval: The search on DuckDuckGo was successful in providing context about Naver News URL structures, though direct access to the site was previously blocked. Verdict: Success
# INFO     [Agent]   🧠 Memory: I have tried to access Naver News multiple times and faced 403 Access Denied. I am now following the user's explicit command to navigate to https://news.naver.com again as the starting action for this sequence. I have found references to potential URL structures like /section/100 or sid1=100 in search results.
# INFO     [Agent]   🎯 Next goal: Navigate to https://news.naver.com as the mandatory first step and then attempt to locate the '정치' section URL.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 9:
# INFO     [Agent]   ⚠️ Eval: The navigation to https://news.naver.com resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: I have attempted to access Naver News multiple times (desktop and mobile) but am consistently blocked by the server. I am following the user's mandatory instruction to navigate to the main page first. I have identified from previous searches that the Politics section URL is likely https://news.naver.com/section/100 or includes sid1=100.
# INFO     [Agent]   🎯 Next goal: Navigate to Naver News and take a screenshot to confirm the access status, then attempt to find the '정치' section link in the DOM.
# INFO     [Agent]   ▶️  [1/3] navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] Action "navigate" terminates sequence — skipping 2 remaining action(s)
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 10:
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=5, stagnation=0)
# INFO     [Agent]   👍 Eval: The navigation to https://news.naver.com was successful in terms of reaching the server, but resulted in an 'Access Denied' error. Verdict: Failure (due to server-side blocking).
# INFO     [Agent]   🧠 Memory: I am currently blocked from accessing news.naver.com directly. Search results indicate the Politics section URL is https://news.naver.com/section/100. I will try to verify this URL directly.
# INFO     [Agent]   🎯 Next goal: Navigate to the suspected '정치' section URL to verify its existence and accessibility.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com/section/100, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 11:
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=5, stagnation=0)
# INFO     [Agent]   ⚠️ Eval: The navigation to the suspected Politics section URL (https://news.naver.com/section/100) resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: I am consistently blocked from Naver News (403 error). I have identified the likely Politics section URL as https://news.naver.com/section/100 from search results, but I cannot verify it on the site itself. I am following the user's mandatory first step to navigate to the main page.
# INFO     [Agent]   🎯 Next goal: Navigate to https://news.naver.com as the mandatory first step and check for accessibility.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 12:
# INFO     [Agent] Step budget warning: 12/15 (80%)
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=6, stagnation=0)
# ERROR    [gemini-flash-latest] 💥 API call failed after 20.99s: ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# WARNING  [Agent] ⚠️ LLM error (ModelProviderError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}) but no fallback_llm configured
# WARNING  [Agent] ❌ Result failed 1/6 times: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 13:
# INFO     [Agent] Step budget warning: 13/15 (86%)
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=6, stagnation=1)
# INFO     [Agent]   ⚠️ Eval: The previous navigation to Naver News resulted in an Access Denied error. Verdict: Failure (Server-side block).
# INFO     [Agent]   🧠 Memory: Consistently blocked from accessing news.naver.com (403 error). Search results from previous steps indicate the Politics section URL is https://news.naver.com/section/100. This is the penultimate step.
# INFO     [Agent]   🎯 Next goal: Navigate to Naver News as the mandatory first step and check for accessibility.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 14:
# INFO     [Agent] Step budget warning: 14/15 (93%)
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=7, stagnation=0)
# ERROR    [gemini-flash-latest] 💥 API call failed after 1.74s: ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# WARNING  [Agent] ⚠️ LLM error (ModelProviderError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}) but no fallback_llm configured
# WARNING  [Agent] ❌ Result failed 1/6 times: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 15:
# INFO     [Agent] 🔁 Loop detection nudge injected (repetition=7, stagnation=1)
# INFO     [Agent]   ⚠️ Eval: The navigation to Naver News resulted in an 'Access Denied' error, making it impossible to find the element on the page. Verdict: Failure (due to server-side blocking).
# INFO     [Agent]   🧠 Memory: Consistently blocked from news.naver.com with a 403 error across multiple attempts. Identified the Politics section URL as https://news.naver.com/section/100 via external search engine results.
# INFO     [Agent]   🎯 Next goal: Provide the final report to the user and terminate the task.
# INFO     [Agent]   ▶️   done: text: 네이버 뉴스 사이트 접속 시도 결과, 서버로부터 'Access Denied' (403 Forbidden) 오류가 발생하여 페이지 내부의 메뉴 요소를 직접 확인할 수 없었습니다.
#
# [작업 결과 보고]
# 1. '정치' 섹션 메뉴 URL: https://news.naver.c..., success: False, files_to_display: []
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
# 📄  Final Result:
# 네이버 뉴스 사이트 접속 시도 결과, 서버로부터 'Access Denied' (403 Forbidden) 오류가 발생하여 페이지 내부의 메뉴 요소를 직접 확인할 수 없었습니다.
#
# [작업 결과 보고]
# 1. '정치' 섹션 메뉴 URL: https://news.naver.com/section/100 (외부 검색을 통해 확인된 정보이며, 사이트 차단으로 인해 직접 검증은 불가함)
# 2. 현재 페이지 URL: https://news.naver.com
# 3. 상태: 확인 불가 (서버 접속 차단됨)
#
# 요소를 find_elements로 찾거나 시각적으로 파악하는 것이 사이트 보안 정책으로 인해 제한되었습니다.
#
#
# INFO     [Agent]
# ⚖️  Judge Verdict: ❌ FAIL
#    Failure Reason: The agent was blocked by the website's anti-bot system (403 Forbidden), preventing it from accessing the Naver News page to locate the 'Politics' section menu as requested. Consequently, it could not provide the required CSS selectors or verify the information visually on the target site.
#    The agent was unable to complete the task as requested because it was blocked by Naver's anti-bot measures (403 Forbidden). Although the agent successfully navigated to the URL in the first step, subsequent attempts to interact with the page or view it visually resulted in an 'Access Denied' screen. The agent correctly identified the 'Politics' section URL (https://news.naver.com/section/100) using an external search engine (DuckDuckGo) as a fallback, but it could not fulfill the specific instructions to find the element within the page's DOM or identify it visually on the site. Since the agent was blocked from the target website throughout the trajectory, it could not verify the information or provide the required CSS selectors from the actual page state. The agent correctly reported its failure and the reason for it.
#
# INFO     [Agent]
# INFO     [Agent] Failed because of CAPTCHA? For better browser stealth, try:
# INFO     [Agent]    agent = Agent(task="첫 번째 액션으로 ...", browser=Browser(use_cloud=True))
# INFO     [Agent]
# INFO     [Agent] Did the Agent not work as expected? Let us fix this!
# INFO     [Agent]    Open a short issue on GitHub: https://github.com/browser-use/browser-use/issues
# ✅ [browse_web 완료] 네이버 뉴스 사이트 접속 시도 결과, 서버로부터 'Access Denied' (403 Forbidden) 오류가 발생하여 페이지 내부의 메뉴 요소를 직접 확인할 수 없었습니다.
#
# [작업 결과 보고]
# 1. '정치' 섹션 메뉴 URL: https://news.naver.com/section/100 (외부 검색을 통해 확인된 정보이며, 사이트 차단으로 인해 직접...
#
# 📐 [get_page_structure] https://news.naver.com/section/100
#    🎯 분석 목표: 정치 섹션의 최신 기사 제목과 기사 상세 URL
# [INIT].... → Crawl4AI 0.8.0
# [ERROR]... × https://news.naver.com/section/100                 | Error: Unexpected error in _crawl_web at line 940
# in _crawl_web (../../../usr/local/python/3.12.1/lib/python3.12/site-packages/crawl4ai/async_crawler_strategy.py):
# Error: Wait condition failed: Timeout after 15000ms waiting for selector 'main a'
#
# Code context:
#  935                       timeout = config.wait_for_timeout if config.wait_for_timeout is not None else
# config.page_timeout
#  936                       await self.smart_wait(
#  937                           page, config.wait_for, timeout=timeout
#  938                       )
#  939                   except Exception as e:
#  940 →                     raise RuntimeError(f"Wait condition failed: {str(e)}")
#  941
#  942               # Update image dimensions if needed
#  943               if not self.browser_config.text_mode:
#  944                   update_image_dimensions_js = load_js_script("update_image_dimensions")
#  945                   try:
# INFO     [Agent] 🎯 Task: 첫 번째 액션으로 반드시 navigate를 실행하여 아래 URL로 이동하세요.
# 현재 브라우저 상태와 관계없이 즉시 이동부터 시작합니다.
#
# [이동할 URL]
# https://news.naver.com/section/100
#
# [이동 후 수행할 작업]
#     기사 목록의 제목과 기사 URL을 가리키는 CSS 셀렉터를 찾아주세요.
# (예: .section_article_item .sa_text_title)
# 또한, 데이터가 잘 로드되었는지 확인하고 샘플 텍스트 2~3개를 알려주세요.
#     [결과 보고 규칙]
#     - 작업 결과를 구체적으로 보고하세요.
#     - 요소를 find_elements로 찾기 어렵다면, screenshot으로 화면을 직접 확인한 뒤
#     시각적으로 목표 요소를 파악하세요.
#     - CSS 셀렉터가 필요한 작업이라면:
#         tag + class/id 조합으로 작성하세요. 예) "a.sa_text_title", "#dic_area"
#         "a", "div" 처럼 태그만 있는 셀렉터는 사용 금지.
#     - 확인 불가능한 정보는 "확인 불가"로 명시하세요.
#     - 작업 완료 후 현재 페이지 URL과 상태를 함께 보고하세요.
#
# INFO     [Agent] 📦 Newer version available: 0.12.0 (current: 0.11.13). Upgrade with: uv add browser-use==0.12.0
# INFO     [Agent] Starting a browser-use agent with version 0.11.13, with provider=google and model=gemini-flash-latest
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 1:
# 🌐 [browse_web] → https://news.naver.com/section/100
#    📋 작업: 기사 목록의 제목과 기사 URL을 가리키는 CSS 셀렉터를 찾아주세요.
# (예: .section_article_item .sa_text_title)
# 또한, 데이터가 잘 로드되었는지 확인하고 샘플 텍스트 2~3개를 알려주세요.
# INFO     [Agent]   ❔ Eval: Initial step, no previous goal to evaluate.
# INFO     [Agent]   🧠 Memory: Starting the task by navigating to the Naver News Politics section (100). Need to identify CSS selectors for titles and URLs and provide samples.
# INFO     [Agent]   🎯 Next goal: Navigate to the specified Naver News section URL.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com/section/100, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 2:
# INFO     [Agent]   ⚠️ Eval: The navigation to https://news.naver.com/section/100 resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Encountered 'Access Denied' on direct navigation to the Politics section. Attempting to access via the main news page.
# INFO     [Agent]   🎯 Next goal: Navigate to the Naver News home page to bypass the access block.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com/, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com/
# INFO     [Agent] 📋 Plan updated with 5 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 3:
# INFO     [Agent]   ⚠️ Eval: The navigation to the Naver News home page also resulted in 'Access Denied'. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct access to news.naver.com is being blocked by the server (Access Denied). I am following the user's strict instruction to navigate to the Politics section URL again.
# INFO     [Agent]   🎯 Next goal: Navigate to the Politics section of Naver News as requested by the user.
# INFO     [Agent]   ▶️   navigate: url: https://news.naver.com/section/100, new_tab: False
# INFO     [tools] 🔗 Navigated to https://news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 5 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 4:
# INFO     [Agent]   ⚠️ Eval: The navigation to the Politics section URL failed again with an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct access to news.naver.com is blocked (403 Access Denied). I have tried direct navigation to the section and the home page. Now attempting to find an entry point via a search engine.
# INFO     [Agent]   🎯 Next goal: Search for '네이버 뉴스 정치' on DuckDuckGo to find an alternative way to access the page.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 정치, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 정치'
# INFO     [Agent] 📋 Plan updated with 5 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 5:
# INFO     [Agent]   👍 Eval: The search on DuckDuckGo was successful and provided several links to Naver News. Verdict: Success
# INFO     [Agent]   🧠 Memory: Direct navigation to Naver News resulted in 403 Access Denied. Currently trying to enter the site through DuckDuckGo search results to bypass the block.
# INFO     [Agent]   🎯 Next goal: Click on the '정치 - Naver' link in the search results to access the Politics section.
# INFO     [Agent]   ▶️   click: index: 6354
# INFO     [tools] 🖱️ Clicked a "정치
# 정치 - Naver"
# INFO     [Agent] 📋 Plan updated with 6 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 6:
# INFO     [Agent]   ⚠️ Eval: The attempt to access Naver News via DuckDuckGo search results also resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct and search-referred access to news.naver.com is blocked by a 403 error. I have tried 3 times. Next, I will try the mobile site and then search for selectors externally if needed.
# INFO     [Agent]   🎯 Next goal: Try to access the mobile version of the Naver News Politics section to bypass the block.
# INFO     [Agent]   ▶️  [1/2] write_file: file_name: todo.md, content: # Naver News Extraction Task
#
# - [x] Navigate to Politics section (Blocked)
# - [x] Try search engine entry (Blocked)
# - [ ] Try mobile site access
# - [ ] ..., append: False, trailing_newline: True, leading_newline: False
# INFO     [tools] 💾 Data written to file todo.md successfully. File location: /tmp/browser_use_agent_069a1132-e367-7ed1-8000-d6bc2d90a856_1772163886/browseruse_agent_data/todo.md
# INFO     [Agent]   ▶️  [2/2] navigate: url: https://m.news.naver.com/section/100, new_tab: True
# INFO     [tools] 🔗  Opened new tab with url https://m.news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 7 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 7:
# INFO     [Agent]   ⚠️ Eval: The attempt to access the mobile version of Naver News also resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct and mobile access to news.naver.com is blocked by 403 errors. I have tried 4 different entry methods. I will now search for known CSS selectors for Naver News Politics section to fulfill the request as much as possible.
# INFO     [Agent]   🎯 Next goal: Search for Naver News article CSS selectors on DuckDuckGo to provide the requested technical information.
# INFO     [Agent]   ▶️   search: query: naver news section article title css selector, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for 'naver news section article title css selector'
# INFO     [Agent] 📋 Plan updated with 6 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 8:
# INFO     [Agent]   👍 Eval: The search for CSS selectors on DuckDuckGo was successful in providing general crawling information, but I need to confirm the specific selectors for the section pages. Verdict: Success
# INFO     [Agent]   🧠 Memory: Direct access to Naver News is blocked (403). I am now gathering CSS selectors from external sources. Current candidates for titles: '.sa_text_title', 'a.sa_text_title'. Need to verify if these are still valid for the section/100 page.
# INFO     [Agent]   🎯 Next goal: Search for specific Naver News section page CSS selectors in Korean to ensure accuracy.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 섹션 기사 제목 CSS 셀렉터, engine: duckduckgo
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 섹션 기사 제목 CSS 셀렉터'
# INFO     [Agent] 📋 Plan updated with 6 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 9:
# INFO     [Agent]   👍 Eval: The search for CSS selectors was successful in providing general information, but specific verification on the target page remains impossible due to persistent 403 errors. Verdict: Success (in information gathering) / Failure (in page access)
# INFO     [Agent]   🧠 Memory: Tried direct, mobile, and search-referred access to Naver News; all blocked with 403. Identified potential selectors '.sa_text_title' and 'a.sa_text_title' from search results. Proceeding to confirm these for the specific section layout.
# INFO     [Agent]   🎯 Next goal: Search for the specific HTML structure of Naver News section pages to confirm selectors for titles and URLs.
# INFO     [Agent]   ▶️   search: query: 네이버 뉴스 section/100 기사 제목 CSS 선택자 구조, engine: duckduckgo
# WARNING  [BrowserSession] ⚠️ Page readiness timeout (3.0s, 3102ms) for https://duckduckgo.com/?q=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%89%B4%EC%8A%A4+section%2F100+%EA%B8%B0%EC%82%AC+%EC%A0%9C%EB%AA%A9+CSS+%EC%84%A0%ED%83%9D%EC%9E%90+%EA%B5%AC%EC%A1%B0
# INFO     [tools] 🔍  Searched Duckduckgo for '네이버 뉴스 section/100 기사 제목 CSS 선택자 구조'
# INFO     [Agent] 📋 Plan updated with 6 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 10:
# ERROR    [gemini-flash-latest] 💥 API call failed after 10.69s: ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# WARNING  [Agent] ⚠️ LLM error (ModelProviderError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}) but no fallback_llm configured
# WARNING  [Agent] ❌ Result failed 1/6 times: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 11:
# INFO     [Agent]   👍 Eval: The search for CSS selectors was successful in providing general information, but specific verification on the target page remains impossible due to persistent 403 errors. Verdict: Success (in information gathering) / Failure (in page access)
# INFO     [Agent]   🧠 Memory: Tried direct, mobile, and search-referred access to Naver News; all blocked with 403. Identified potential selectors '.sa_text_title' and 'a.sa_text_title' from search results. Now attempting to verify these via a technical blog post.
# INFO     [Agent]   🎯 Next goal: Navigate to a technical blog post from search results to confirm the CSS selectors used in the Naver News section layout.
# INFO     [Agent]   ▶️   click: index: 4235
# INFO     [tools] 🖱️ Clicked a "#23_네이버 뉴스 페이지 실습 - 벨로그"
# INFO     [Agent] 📋 Plan updated with 6 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 12:
# INFO     [Agent] Step budget warning: 12/15 (80%)
# INFO     [Agent]   👍 Eval: The navigation to the Velog blog post was successful. Verdict: Success
# INFO     [Agent]   🧠 Memory: Direct access to Naver News is blocked (403). I am gathering CSS selectors from external technical sources. Current potential selectors: Title - 'a.sa_text_title', URL - 'a.sa_text_title' (href). I have 3 steps left.
# INFO     [Agent]   🎯 Next goal: Search the current page for specific CSS selector patterns related to Naver News to confirm findings.
# INFO     [Agent]   ▶️   search_page: pattern: sa_text, regex: False, case_sensitive: False, context_chars: 100, css_scope: None, max_results: 10
# INFO     [tools] 🔎 Searched page for "sa_text": 0 matches found.
# INFO     [Agent] 📋 Plan updated with 5 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 13:
# INFO     [Agent] Step budget warning: 13/15 (86%)
# INFO     [Agent]   ⚠️ Eval: The search for 'sa_text' on the current page yielded no results, suggesting the blog might use different or older selectors. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Direct access to Naver News is blocked (403). Currently on a Velog blog post about Naver News to find CSS selectors. 2 steps remaining.
# INFO     [Agent]   🎯 Next goal: Extract CSS selectors for article titles and URLs from the current technical blog post.
# INFO     [Agent]   ▶️   extract: query: Find CSS selectors used for Naver News article titles and URLs mentioned in this blog post. Look for class names like 'sa_text_title' or similar., extract_links: False, start_from_char: 0
# INFO     [tools] 📄 <url>
# https://velog.io/@hwanginchang/23%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%89%B4%EC%8A%A4-%ED%8E%98%EC%9D%B4%EC%A7%80-%EC%8B%A4%EC%8A%B5
# </url>
# <query>
# Find CSS selectors used for Naver News article titles and URLs mentioned in this blog post. Look for class names like 'sa_text_title' or similar.
# </query>
# <result>
# Based on the blog post provided, the specific class name `sa_text_title` is not mentioned. However, the following CSS selectors are used for the Naver News article titles and links in the practice code:
#
# *   **Article Headline (Title):** `#news_headline .news-headline-lists .headline-info p`
# *   **Article Link (URL):** `#news_headline .news-headline-lists li a`
# *   **Article Category/Header:** `#news_headline .news-headline-lists li a article h3`
# *   **Headline Info Container:** `#news_headline .news-headline-lists .headline-info`
# </result>
# INFO     [Agent] 📋 Plan updated with 5 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 14:
# INFO     [Agent] Step budget warning: 14/15 (93%)
# INFO     [Agent]   👍 Eval: The extraction from the technical blog was successful, providing alternative selectors, though they appear to be for a practice/clone page rather than the live site. Verdict: Success in information gathering.
# INFO     [Agent]   🧠 Memory: Attempted multiple access methods to Naver News (Direct, Mobile, Search Referral) - all blocked by 403 error. Identified CSS selectors via external research. Final step reached.
# INFO     [Agent]   🎯 Next goal: Submit the final report with the gathered CSS selectors and the access status.
# INFO     [Agent]   ▶️   done: text: 네이버 뉴스 정치 섹션(https://news.naver.com/section/100)에 대한 작업 결과입니다.
#
# 1. **접속 상태**: 확인 불가 (403 Access Denied)
#    - 직접 접속, 모바일 페이지(m.news.naver.com), 검색 엔진을 ..., success: False, files_to_display: []
# INFO     [Agent]
# 📄  Final Result:
# 네이버 뉴스 정치 섹션(https://news.naver.com/section/100)에 대한 작업 결과입니다.
#
# 1. **접속 상태**: 확인 불가 (403 Access Denied)
#    - 직접 접속, 모바일 페이지(m.news.naver.com), 검색 엔진을 통한 우회 접속을 모두 시도하였으나 서버에서 접근을 차단하여 페이지 내용을 직접 확인할 수 없었습니다.
#
# 2. **기사 목록 CSS 셀렉터 (외부 기술 자료 및 검색 기반)**:
#    - **기사 제목**: `a.sa_text_title` 또는 `strong.sa_text_strong`
#    - **기사 URL**: `a.sa_text_title` (해당 요소의 href 속성)
#    - *참고: 네이버 뉴스의 최신 레이아웃(sa_item 구조) 기준입니다.*
#
# 3. **샘플 텍스트 (2~3개)**:
#    - 확인 불가 (접근 차단으로 인해 실제 데이터를 로드하지 못함)
#
# 4. **현재 페이지 URL 및 상태**:
#    - URL: https://news.naver.com/section/100
#    - 상태: 403 Forbidden (Access Denied)
#
#
# INFO     [Agent]
# ⚖️  Judge Verdict: ❌ FAIL
#    Failure Reason: The agent was blocked by the website's anti-bot measures (403 Forbidden), preventing it from accessing the page content. Consequently, it could not verify if the data loaded or provide the requested sample texts from the live site. Although it found CSS selectors through external search, the primary task of interacting with the specific URL was not completed.
#    🤖 Captcha Detected: Agent encountered captcha challenges
#    👉 🥷 Use Browser Use Cloud for the most stealth browser infra: https://docs.browser-use.com/customize/browser/remote
#    The agent followed the initial instruction to navigate to the specified URL. However, it encountered a 403 Forbidden (Access Denied) error, indicating that Naver News blocked the automated browser. The agent attempted several reasonable workarounds, including trying the mobile version of the site and attempting to enter via a search engine, but remained blocked. While the agent successfully found the likely CSS selectors by searching external technical blogs, it was unable to fulfill the core requirements of verifying the data load and providing sample texts from the actual page. The agent correctly identified the failure and reported it according to the rules, but since the user's primary goal of data verification and sampling was not met, the verdict is false. The task was effectively impossible for the agent due to site-level bot protection.
#
# INFO     [Agent]
# INFO     [Agent] Failed because of CAPTCHA? For better browser stealth, try:
# INFO     [Agent]    agent = Agent(task="첫 번째 액션으로 ...", browser=Browser(use_cloud=True))
# INFO     [Agent]
# INFO     [Agent] Did the Agent not work as expected? Let us fix this!
# INFO     [Agent]    Open a short issue on GitHub: https://github.com/browser-use/browser-use/issues
# ✅ [browse_web 완료] 네이버 뉴스 정치 섹션(https://news.naver.com/section/100)에 대한 작업 결과입니다.
#
# 1. **접속 상태**: 확인 불가 (403 Access Denied)
#    - 직접 접속, 모바일 페이지(m.news.naver.com), 검색 엔진을 통한 우회 접속을 모두 시도하였으나 서버에서 접근을 차단하여 페이지 내용을 직접 확인할 수...
# INFO     [backoff] Backing off send_request(...) for 0.2s (requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='eu.i.posthog.com', port=443): Read timed out. (read timeout=15))
# 📐 [get_page_structure] https://m.news.naver.com/section/100
#    🎯 분석 목표: 최신 기사 제목과 상세 URL (정치 섹션)
# [INIT].... → Crawl4AI 0.8.0
# [ERROR]... × https://m.news.naver.com/section/100               | Error: Unexpected error in _crawl_web at line 940
# in _crawl_web (../../../usr/local/python/3.12.1/lib/python3.12/site-packages/crawl4ai/async_crawler_strategy.py):
# Error: Wait condition failed: Timeout after 15000ms waiting for selector 'main a'
#
# Code context:
#  935                       timeout = config.wait_for_timeout if config.wait_for_timeout is not None else
# config.page_timeout
#  936                       await self.smart_wait(
#  937                           page, config.wait_for, timeout=timeout
#  938                       )
#  939                   except Exception as e:
#  940 →                     raise RuntimeError(f"Wait condition failed: {str(e)}")
#  941
#  942               # Update image dimensions if needed
#  943               if not self.browser_config.text_mode:
#  944                   update_image_dimensions_js = load_js_script("update_image_dimensions")
#  945                   try:
# INFO     [Agent] 🎯 Task: 첫 번째 액션으로 반드시 navigate를 실행하여 아래 URL로 이동하세요.
# 현재 브라우저 상태와 관계없이 즉시 이동부터 시작합니다.
#
# [이동할 URL]
# https://m.news.naver.com/section/100
#
# [이동 후 수행할 작업]
#     정치 섹션의 기사 제목 5개를 가져오세요.
# (가능하면 m.news.naver.com/section/100 에서 시도해 보세요)
#     [결과 보고 규칙]
#     - 작업 결과를 구체적으로 보고하세요.
#     - 요소를 find_elements로 찾기 어렵다면, screenshot으로 화면을 직접 확인한 뒤
#     시각적으로 목표 요소를 파악하세요.
#     - CSS 셀렉터가 필요한 작업이라면:
#         tag + class/id 조합으로 작성하세요. 예) "a.sa_text_title", "#dic_area"
#         "a", "div" 처럼 태그만 있는 셀렉터는 사용 금지.
#     - 확인 불가능한 정보는 "확인 불가"로 명시하세요.
#     - 작업 완료 후 현재 페이지 URL과 상태를 함께 보고하세요.
#
# INFO     [Agent] 📦 Newer version available: 0.12.0 (current: 0.11.13). Upgrade with: uv add browser-use==0.12.0
# INFO     [Agent] Starting a browser-use agent with version 0.11.13, with provider=google and model=gemini-flash-latest
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 1:
# 🌐 [browse_web] → https://m.news.naver.com/section/100
#    📋 작업: 정치 섹션의 기사 제목 5개를 가져오세요.
# (가능하면 m.news.naver.com/section/100 에서 시도해 보세요)
# INFO     [Agent]   ❔ Eval: Agent initialized. No previous goal to evaluate.
# INFO     [Agent]   🧠 Memory: Starting the task to extract 5 article titles from Naver News Politics section. First step is to navigate to the target URL.
# INFO     [Agent]   🎯 Next goal: Navigate to https://m.news.naver.com/section/100 to access the Politics news section.
# INFO     [Agent]   ▶️   navigate: url: https://m.news.naver.com/section/100, new_tab: False
# INFO     [tools] 🔗 Navigated to https://m.news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 2:
# INFO     [Agent]   ⚠️ Eval: The navigation to https://m.news.naver.com/section/100 failed with an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Encountered Access Denied on m.news.naver.com. Switching to the desktop version tab (29B3) to check if it's accessible.
# INFO     [Agent]   🎯 Next goal: Switch to the desktop version of Naver News Politics in tab 29B3.
# INFO     [Agent]   ▶️   switch: tab_id: 29B3
# INFO     [tools] 🔄  Switched to tab #29B3
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 3:
# INFO     [Agent]   ⚠️ Eval: The switch to the desktop tab also resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Tried both mobile and desktop URLs for Naver News Politics, both blocked by Akamai. Re-attempting navigation to the mobile URL as per strict user instructions.
# INFO     [Agent]   🎯 Next goal: Navigate to the mobile Naver News Politics section as requested.
# INFO     [Agent]   ▶️   navigate: url: https://m.news.naver.com/section/100, new_tab: False
# WARNING  [BrowserSession] ⚠️ Page readiness timeout (8.0s, 8028ms) for https://m.news.naver.com/section/100
# INFO     [tools] 🔗 Navigated to https://m.news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 4:
# ERROR    [gemini-flash-latest] 💥 API call failed after 21.55s: ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# WARNING  [Agent] ⚠️ LLM error (ModelProviderError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}) but no fallback_llm configured
# WARNING  [Agent] ❌ Result failed 1/6 times: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 5:
# INFO     [Agent]   ⚠️ Eval: The previous navigation attempt resulted in an 'Access Denied' error from the server. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Tried navigating to the mobile Naver Politics section multiple times but encountered Access Denied. The user request is very specific about starting with a navigation to this URL.
# INFO     [Agent]   🎯 Next goal: Navigate to the specified Naver News Politics URL as requested by the user.
# INFO     [Agent]   ▶️   navigate: url: https://m.news.naver.com/section/100, new_tab: False
# WARNING  [BrowserSession] ⚠️ Page readiness timeout (3.0s, 3067ms) for https://m.news.naver.com/section/100
# INFO     [tools] 🔗 Navigated to https://m.news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 3 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 6:
# INFO     [Agent]   ⚠️ Eval: The navigation to https://m.news.naver.com/section/100 resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: Repeatedly blocked by Akamai when accessing Naver News Politics. Tried both mobile and desktop URLs. Current state is 'Access Denied'.
# INFO     [Agent]   🎯 Next goal: Take a screenshot to confirm the 'Access Denied' state and try navigating to the Naver News home page to check domain accessibility.
# INFO     [Agent]   ▶️  [1/2] screenshot: file_name: access_denied_check.png
# INFO     [tools] 📸 Screenshot saved to access_denied_check.png. Full path: /tmp/browser_use_agent_069a114d-f411-737f-8000-ba00760255b9_1772164319/browseruse_agent_data/access_denied_check.png
# INFO     [Agent]   ▶️  [2/2] navigate: url: https://m.news.naver.com/, new_tab: True
# INFO     [tools] 🔗  Opened new tab with url https://m.news.naver.com/
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 7:
# INFO     [Agent]   ⚠️ Eval: The navigation to the Naver News home page also resulted in an 'Access Denied' error. Verdict: Failure
# INFO     [Agent]   🧠 Memory: I have repeatedly encountered 'Access Denied' when trying to access Naver News. The user's latest request strictly mandates a navigation to the Politics section URL as the starting step.
# INFO     [Agent]   🎯 Next goal: Navigate to https://m.news.naver.com/section/100 as explicitly requested by the user.
# INFO     [Agent]   ▶️   navigate: url: https://m.news.naver.com/section/100, new_tab: False
# INFO     [tools] 🔗 Navigated to https://m.news.naver.com/section/100
# INFO     [Agent] 📋 Plan updated with 4 steps
# INFO     [Agent]
#
# INFO     [Agent] 📍 Step 8:
# INFO     [Agent]   ⚠️ Eval: The navigation to the requested URL was executed but resulted in an 'Access Denied' error. Verdict: Failure (due to server-side blocking).
# INFO     [Agent]   🧠 Memory: Repeatedly blocked from m.news.naver.com/section/100. Attempting to bypass the block by using Naver Search to find the 5 political news titles. Will report the final state and URL as requested.
# INFO     [Agent]   🎯 Next goal: Navigate to Naver Search to find the latest political news titles as an alternative to the blocked section page.
# INFO     [Agent]   ▶️   navigate: url: https://search.naver.com/search.naver?where=news&query=%EC%A0%95%EC%B9%98&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&off..., new_tab: False
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 0 | ▶️ 1 | ✅ 49 ➡️ 31 👂) handler browser_use.browser.watchdog_base.BrowserSession.on_NavigateToUrlEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.BrowserSession.on_NavigateToUrlEvent(?▶ NavigateToUrlEvent#0f46 🏃)
# ERROR    [BrowserSession] Navigation failed: RuntimeError: Page.navigate() timed out after 20.0s (20001ms) for https://search.naver.com/search.naver?where=news&query=%EC%A0%95%EC%B9%98&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Aall&is_sug_officeid=0&office_category=0&service_area=0
# ERROR    [BrowserSession] 🚌 [BrowserSession.on_NavigateToUrlEvent(#0f46)]          ❌ Failed (23.01s): RuntimeError: Page.navigate() timed out after 20.0s (20001ms) for https://search.naver.com/search.naver?where=news&query=%EC%A0%95%EC%B9%98&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Aall&is_sug_officeid=0&office_category=0&service_area=0
# ERROR    [BrowserSession] ❌ Navigation failed: Page.navigate() timed out after 20.0s (20001ms) for https://search.naver.com/search.naver?where=news&query=%EC%A0%95%EC%B9%98&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Aall&is_sug_officeid=0&office_category=0&service_area=0
# INFO     [Agent] 📋 Plan updated with 4 steps
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) handler browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#5af2 🏃)
# WARNING  [Agent] ❌ Result failed 2/6 times:
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] ⏱️  TIMEOUT ERROR - Handling took more than 30.0s for EventBus_73ae7750.browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#5af2 ✅)
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] 📣 BrowserStateRequestEvent#5af2                                       33s
# WARNING  [bubus]    ☑️ browser_use.browser.watchdog_base.DownloadsWatchdog.on_BrowserStateRequestEvent(#5af2)     3s/30s   ✓
# WARNING  [bubus]       📣 NavigationCompleteEvent#0d52                                  30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.DownloadsWatchdog.on_NavigationCompleteEvent(#0d52) 🔜    /30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.SecurityWatchdog.on_NavigationCompleteEvent(#0d52) 🔜    /30s
# WARNING  [bubus]    ⏰ browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(#5af2) ⌛️ 30s/30s   ⬅️ TIMEOUT HERE ⏰
# WARNING  [bubus]
# ================================================================================
#
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) handler browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#7e57 🏃)
# WARNING  [Agent] ❌ Result failed 3/6 times:
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] ⏱️  TIMEOUT ERROR - Handling took more than 30.0s for EventBus_73ae7750.browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#7e57 ✅)
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] 📣 BrowserStateRequestEvent#7e57                                       33s
# WARNING  [bubus]    ☑️ browser_use.browser.watchdog_base.DownloadsWatchdog.on_BrowserStateRequestEvent(#7e57)     3s/30s   ✓
# WARNING  [bubus]       📣 NavigationCompleteEvent#1c47                                  30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.DownloadsWatchdog.on_NavigationCompleteEvent(#1c47) 🔜    /30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.SecurityWatchdog.on_NavigationCompleteEvent(#1c47) 🔜    /30s
# WARNING  [bubus]    ⏰ browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(#7e57) ⌛️ 30s/30s   ⬅️ TIMEOUT HERE ⏰
# WARNING  [bubus]
# ================================================================================
#
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) handler browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#41bb 🏃)
# WARNING  [Agent] ❌ Result failed 4/6 times:
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] ⏱️  TIMEOUT ERROR - Handling took more than 30.0s for EventBus_73ae7750.browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#41bb ✅)
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] 📣 BrowserStateRequestEvent#41bb                                       33s
# WARNING  [bubus]    ☑️ browser_use.browser.watchdog_base.DownloadsWatchdog.on_BrowserStateRequestEvent(#41bb)     3s/30s   ✓
# WARNING  [bubus]       📣 NavigationCompleteEvent#b5e2                                  30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.DownloadsWatchdog.on_NavigationCompleteEvent(#b5e2) 🔜    /30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.SecurityWatchdog.on_NavigationCompleteEvent(#b5e2) 🔜    /30s
# WARNING  [bubus]    ⏰ browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(#41bb) ⌛️ 30s/30s   ⬅️ TIMEOUT HERE ⏰
# WARNING  [bubus]
# ================================================================================
#
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) handler browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#1268 🏃)
# WARNING  [Agent] ❌ Result failed 5/6 times:
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] ⏱️  TIMEOUT ERROR - Handling took more than 30.0s for EventBus_73ae7750.browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#1268 ✅)
# WARNING  [bubus] ================================================================================
# WARNING  [bubus] 📣 BrowserStateRequestEvent#1268                                       33s
# WARNING  [bubus]    ☑️ browser_use.browser.watchdog_base.DownloadsWatchdog.on_BrowserStateRequestEvent(#1268)     3s/30s   ✓
# WARNING  [bubus]       📣 NavigationCompleteEvent#9859                                  30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.DownloadsWatchdog.on_NavigationCompleteEvent(#9859) 🔜    /30s
# WARNING  [bubus]          🔜 browser_use.browser.watchdog_base.SecurityWatchdog.on_NavigationCompleteEvent(#9859) 🔜    /30s
# WARNING  [bubus]    ⏰ browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(#1268) ⌛️ 30s/30s   ⬅️ TIMEOUT HERE ⏰
# WARNING  [bubus]
# ================================================================================
#
# ERROR    [Agent] ❌ Result failed 6/6 times:
# ERROR    [Agent] ❌ Stopping due to 5 consecutive failures
# INFO     [Agent]
# INFO     [Agent] Did the Agent not work as expected? Let us fix this!
# INFO     [Agent]    Open a short issue on GitHub: https://github.com/browser-use/browser-use/issues
# WARNING  [bubus] ⚠️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) handler browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent() has been running for >15s on event. Possible slow processing or deadlock.
# (handler could be trying to await its own result or could be blocked by another async task).
# browser_use.browser.watchdog_base.DOMWatchdog.on_BrowserStateRequestEvent(?▶ BrowserStateRequestEvent#b3da 🏃)
# WARNING  [bubus] ⌛️ Agent_55b9🟢(⏳ 1 | ▶️ 0 | ✅ 10 ➡️ 0 👂) Timeout waiting for event bus to be idle after 3.0s (processing: 0)
# WARNING  [bubus] ⌛️ EventBus_73ae7750🟢(⏳ 1 | ▶️ 1 | ✅ 48 ➡️ 31 👂) Timeout waiting for event bus to be idle after 1.0s (processing: 1)
# ✅ [browse_web 완료] 탐색 완료, 결과 반환 없음...
# INFO     [backoff] Backing off send_request(...) for 0.2s (requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='eu.i.posthog.com', port=443): Read timed out. (read timeout=15))
# 📐 [get_page_structure] https://news.naver.com
#    🎯 분석 목표: 메인 뉴스 제목과 링크
# [INIT].... → Crawl4AI 0.8.0
# [ERROR]... × https://news.naver.com                             | Error: Unexpected error in _crawl_web at line 940
# in _crawl_web (../../../usr/local/python/3.12.1/lib/python3.12/site-packages/crawl4ai/async_crawler_strategy.py):
# Error: Wait condition failed: Timeout after 15000ms waiting for selector 'main a'
#
# Code context:
#  935                       timeout = config.wait_for_timeout if config.wait_for_timeout is not None else
# config.page_timeout
#  936                       await self.smart_wait(
#  937                           page, config.wait_for, timeout=timeout
#  938                       )
#  939                   except Exception as e:
#  940 →                     raise RuntimeError(f"Wait condition failed: {str(e)}")
#  941
#  942               # Update image dimensions if needed
#  943               if not self.browser_config.text_mode:
#  944                   update_image_dimensions_js = load_js_script("update_image_dimensions")
#  945                   try:
# ✅ 결과: 1개 Blueprint 생성
#
#   [Blueprint 1]
#     entry_urls : ['https://news.naver.com/section/100']
#     계층 수    : 1
#     Layer 1   : 정치 섹션 기사 목록 | selectors={'title': 'a.sa_text_title > strong.sa_text_strong', 'url': 'a.sa_text_title[href]'}
#
# 📁 파일 저장:
#   💾 저장 완료: /workspaces/codespaces-jupyter/AAWS_project/code_artifacts/blueprint_test1_1.json
# WARNING  [cdp_use.client] Received duplicate response for request 3363 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3364 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3365 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3367 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3368 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3369 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3370 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3371 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3372 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3373 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3374 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3375 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3377 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3378 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3379 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3380 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3381 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3382 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3383 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3384 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3386 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3387 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3388 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3389 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3390 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3392 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3393 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3395 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3396 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3398 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3399 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3401 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3405 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3407 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3408 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3410 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3411 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3413 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3417 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3419 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3420 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3422 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3423 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3425 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3429 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3431 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3432 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3434 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3435 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3437 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3438 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3440 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3456 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3458 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3459 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3461 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3462 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3464 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3465 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3467 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3499 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3501 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3502 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3504 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3505 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3507 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3598 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3600 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3601 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3603 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3604 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3606 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3607 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3609 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3700 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3702 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3703 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3705 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3706 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3708 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3709 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3711 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3802 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3804 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3805 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3807 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3808 - ignoring
# WARNING  [cdp_use.client] Received duplicate response for request 3810 - ignoring

# %% [markdown]
# # Coder 에이전트 재설계

# %%
import os
import subprocess
from dataclasses import dataclass
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.agents.middleware import FilesystemFileSearchMiddleware
from langgraph.checkpoint.memory import InMemorySaver

# ==========================================
# Coder 작업 공간 설정
# ==========================================
ARTIFACT_DIR = os.path.join(project_root, "code_artifacts")
os.makedirs(ARTIFACT_DIR, exist_ok=True)
print(f"✅ 코더 작업 공간: {ARTIFACT_DIR}")

# ==========================================
# Coder Context - 작업 환경 설정 (경로 정보)
# ==========================================
@dataclass
class CoderContext:
    artifact_dir: str   # 코드/결과 저장 디렉토리
    blueprint_path: str # Navigator가 저장한 Blueprint JSON 경로



# ==========================================
# Coder 도구: 파이썬 코드 실행 + 디버깅
# ==========================================
@tool(parse_docstring=True)
def execute_python_code(code: str, filename: str = "scraper.py") -> str:
    """주어진 파이썬 코드를 파일로 저장하고 실행한 뒤 결과(출력/에러)를 반환합니다.
    코드 테스트 및 디버깅에 사용합니다.

    Args:
        code: 실행할 완전한 파이썬 스크립트 (모든 import 포함 필수).
        filename: 저장할 파일명 (기본값: 'scraper.py').
    """
    safe_filename = os.path.basename(filename)
    filepath = os.path.join(ARTIFACT_DIR, safe_filename)
    print(f"\n🐍 [Coder Tool] '{filepath}' 저장 및 실행 중...")

    try:
        with open(filepath, "w", encoding="utf-8") as f:
            f.write(code)

        result = subprocess.run(
            ["python", safe_filename],
            cwd=ARTIFACT_DIR,
            capture_output=True,
            text=True,
            timeout=60  # 스크래핑은 시간이 걸릴 수 있음
        )

        output = result.stdout
        if result.stderr:
            output += f"\n[Error Output]\n{result.stderr}"
        if not output.strip():
            output = "[System] 실행 완료 (출력 없음)"

        return output

    except subprocess.TimeoutExpired:
        return "[Error] 실행 시간(60초) 초과. 타임아웃 설정을 확인하세요."
    except Exception as e:
        return f"[System Error] 실행 오류: {str(e)}"


# ==========================================
# Coder 에이전트 조립
# ==========================================
coder_model = init_chat_model("google_genai:gemini-2.0-flash", temperature=0.1)
coder_checkpointer = InMemorySaver()

CODER_SYSTEM_PROMPT = """
당신은 웹 크롤링 전문 'Coder(개발자)' 에이전트입니다.
Navigator가 전달한 Blueprint를 기반으로, 실행 가능한 파이썬 크롤링 코드를 작성하고 직접 실행합니다.

[작업 환경 (Context)]
- artifact_dir: 코드와 결과 파일을 저장하는 작업 디렉토리
- blueprint_path: 참조할 Blueprint JSON 파일 경로

[Blueprint 해석 방법]
Blueprint의 `layers` 리스트는 탐색 순서대로 정렬되어 있습니다.
- `entry_urls`: 크롤링 시작 URL 목록 (여러 개면 각각 반복)
- `layers[0]`: 최초 진입 URL에서 첫 번째 데이터 수집
- `layers[i].navigate_to_next` 값이 None이 아니면 → 그 셀렉터로 링크 추출 후 다음 계층으로 이동
- `layers[-1]` (마지막): `navigate_to_next=None`, 최종 데이터 수집

[selectors 해석 방법]
Blueprint의 selectors는 {필드명: CSS셀렉터} 딕셔너리입니다.
- 같은 셀렉터가 title과 url에 모두 있으면:
    title → 해당 요소의 .text (또는 .inner_text())
    url   → 해당 요소의 href 속성 (또는 .get_attribute('href'))
- 예) selectors = {"title": "a.sa_text_title", "url": "a.sa_text_title"}
    → elements = page.query_selector_all("a.sa_text_title")
    → title = el.inner_text()
    → url = el.get_attribute("href")

[코드 작성 규칙]
1. `rendering_type`에 따라 라이브러리 선택:
   - "Static SSR"    → `requests` + `BeautifulSoup`
   - "Dynamic CSR/JS" → `playwright` (동기 방식: sync_playwright)
2. Playwright 사용 시 반드시 동기(sync) 방식으로 작성하세요:
   from playwright.sync_api import sync_playwright
   with sync_playwright() as p:
       browser = p.chromium.launch(headless=True)
       page = browser.new_page()
       page.goto(url)
       page.wait_for_load_state("networkidle")
3. `layers` 리스트를 인덱스 순서대로 처리하는 함수를 작성하세요.
4. Blueprint의 selectors를 그대로 사용하세요. 추측으로 변경 금지.
5. 결과는 JSON 파일로 저장하세요 (파일명: scraping_result.json).
6. 코드 작성 후 반드시 `execute_python_code`로 실행하여 결과를 검증하세요.
7. 에러 발생 시 로그를 분석하여 코드를 수정한 뒤 다시 실행하세요. 성공할 때까지 반복합니다.
"""


coder_agent = create_agent(
    model=coder_model,
    system_prompt=CODER_SYSTEM_PROMPT,
    context_schema=CoderContext,
    tools=[execute_python_code],
    middleware=[
        FilesystemFileSearchMiddleware(
            root_path=ARTIFACT_DIR,
            use_ripgrep=True,
            max_file_size_mb=10,
        )
    ],
    checkpointer=coder_checkpointer
)

print("✅ Coder 에이전트 준비 완료")
# Out:
# ✅ 코더 작업 공간: /workspaces/codespaces-jupyter/AAWS_project/code_artifacts
# ✅ Coder 에이전트 준비 완료

# %%
SCRAPING_GOAL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 SCRAPING_GOAL
#
# NameError: name 'SCRAPING_GOAL' is not defined

# %%
from langchain_core.messages import HumanMessage
import json

SCRAPING_GOAL = "정치 섹션의 최신 기사 제목과 URL 5개 수집"

# blueprint_dict가 없으면 저장된 파일에서 로드
if "blueprint_dict" not in dir():
    blueprint_path = os.path.join(ARTIFACT_DIR, "blueprint_test1_1.json")
    with open(blueprint_path, "r", encoding="utf-8") as f:
        blueprint_dict = json.load(f)
    print(f"📂 Blueprint 파일에서 로드: {blueprint_path}")
else:
    print("✅ 기존 blueprint_dict 사용")

# paths_1이 없으면 blueprint_path 직접 지정
if "paths_1" not in dir():
    paths_1 = [os.path.join(ARTIFACT_DIR, "blueprint_test1_1.json")]

# ──────────────────────────────────────────────
# Coder 실행
# ──────────────────────────────────────────────
coder_config = {"configurable": {"thread_id": "coder_session"}}
coder_context = CoderContext(
    artifact_dir=ARTIFACT_DIR,
    blueprint_path=paths_1[0],
)

coder_response = await coder_agent.ainvoke(
    {"messages": [HumanMessage(
        f"아래 Blueprint를 기반으로 '{SCRAPING_GOAL}' 크롤링 코드를 작성하고 직접 실행해주세요.\n\n"
        f"[Blueprint]\n"
        f"{json.dumps(blueprint_dict, ensure_ascii=False, indent=2)}\n\n"
        f"결과는 artifact_dir에 'scraping_result.json'으로 저장하세요."
    )]},
    config=coder_config,
    context=coder_context,
)

print(f"\n✅ Coder 완료!")
print(f"\n🤖 Coder 최종 리포트:\n{coder_response['messages'][-1].content}")

# %%
for m in coder_response['messages']:
    m.pretty_print()

# %%
coder_response = await coder_agent.ainvoke(
    {"messages": [HumanMessage("결과 파일을 보여줘")]},
    config=coder_config,
    context=coder_context)

for m in coder_response['messages']:
    m.pretty_print()

# %%
await shared_browser.stop() # 이제 browser를 닫습니다.

# %% [markdown]
# ### 성공!
#
# ```
# HumanMessage (URL + 목표)
#     ↓
# Navigator 에이전트
#     ├─ get_page_structure() → confidence=low (JS 렌더링 실패)
#     └─ browse_web() → a.sa_text_title 확인
#     ↓
# NavigatorBlueprintCollection
#     { selectors: {"기사 제목": "a.sa_text_title", ...} }
#     ↓
# Coder 에이전트
#     ├─ Playwright 코드 작성
#     └─ execute_python_code() 실행
#     ↓
# scraping_result.json ✅
# ```

# %% [markdown]
# ```
# [
#     {
#         "기사 제목": "與 '尹정권 조작기소 국조 추진위' 설치하자 '李 공취모' 탈퇴 행렬",
#         "기사 URL": "https://n.news.naver.com/mnews/article/656/0000168370"
#     },
#     {
#         "기사 제목": "강기정 광주시장 \"잠시만 광주공항에서 국제선을 운영하겠다\"",
#         "기사 URL": "https://n.news.naver.com/mnews/article/421/0008793751"
#     },
#     {
#         "기사 제목": "與, 법왜곡죄법 수정키로…\"명확성 추가해 위헌 소지 최소화\"",
#         "기사 URL": "https://n.news.naver.com/mnews/article/001/0015924416"
#     },
#     {
#         "기사 제목": "'자사주 의무소각' 3차 상법 개정안 국회 본회의 통과(상보)",
#         "기사 URL": "https://n.news.naver.com/mnews/article/018/0006224624"
#     },
#     {
#         "기사 제목": "TK 통합 불발에 국힘 ‘텃밭’ 영남권 의원들도 뿔났다",
#         "기사 URL": "https://n.news.naver.com/mnews/article/005/0001833933"
#     }
# ]
#
#
# ```

# %% [markdown]
# # 🏆 실습: LangGraph로 파이프라인 자동화하기
#
# 이번 실습에서 우리는 Navigator와 Coder를 **별도로 실행**하고 중간에 직접 Blueprint를 넘겨주었습니다.
#
# ```python
# # 지금까지의 방식: 수동 연결
# nav_response = await navigator_agent.ainvoke(...)   # 1단계 직접 실행
# blueprint = nav_response["structured_response"]      # 중간 결과 수동 추출
# coder_response = await coder_agent.ainvoke(...)      # 2단계 직접 실행
# ```
#
#
# 이 방식은 간단하지만, 한계가 있습니다.
#
# - 사람이 중간에 개입해야 다음 단계가 실행됩니다.
# - 새로운 에이전트가 추가되면 연결 코드가 계속 늘어납니다.
# - 조건에 따른 분기(예: 실패 시 재시도)를 구현하기가 복잡합니다.
#
#
# ## 목표
#
# LangGraph StateGraph를 사용하여 Navigator → Coder 파이프라인을 자동화하세요.
# 사용자가 수집 목표만 입력하면, 아래 흐름이 자동으로 실행되어야 합니다:
#
# ```
# [START]
#    ↓
# [Navigator 노드]  - 목표 URL 탐색 → Blueprint 생성
#    ↓
# [Coder 노드]      - Blueprint 해석 → 코드 작성 → 실행
#    ↓
# [END]
# ```

# %%
from typing_extensions import TypedDict, Annotated
from langgraph.graph import StateGraph, START, END
import json

# ==========================================
# 1. 파이프라인용 State 정의
# ==========================================
class PipelineState(TypedDict):
    """Navigator와 Coder 간의 공유 상태"""
    user_goal: str  # 사용자의 수집 목표
    url: str  # 크롤링할 URL
    blueprint: dict  # Navigator가 생성한 Blueprint
    blueprint_path: str  # Blueprint JSON 파일 경로
    messages: list  # 메시지 히스토리

# ==========================================
# 2. Navigator 노드
# ==========================================
async def navigator_node(state: PipelineState) -> dict:
    """Navigator 에이전트를 실행하여 Blueprint 생성"""
    print(f"🔍 Navigator 시작: {state['user_goal']}")
    print(f"📍 대상 URL: {state['url']}")
    
    nav_config = {"configurable": {"thread_id": "nav_pipeline"}}
    nav_context = NavigatorContext(
        custom_header="Pipeline Automation",
        start_url=state["url"],
    )
    
    # Navigator 실행
    nav_response = await navigator_agent.ainvoke(
        {"messages": [HumanMessage(
            f"목표: {state['user_goal']}\n"
            f"URL: {state['url']}\n\n"
            f"이 페이지를 분석하고 데이터 수집 Blueprint을 생성해주세요."
        )]},
        config=nav_config,
        context=nav_context,
    )
    
    # 응답에서 blueprint 추출
    blueprint = nav_response.get("structured_response", {})
    
    # blueprint를 파일로 저장
    blueprint_path = os.path.join(ARTIFACT_DIR, "pipeline_blueprint.json")
    with open(blueprint_path, "w", encoding="utf-8") as f:
        json.dump(blueprint, f, ensure_ascii=False, indent=2)
    
    print(f"✅ Navigator 완료 - Blueprint 저장: {blueprint_path}")
    
    return {
        "blueprint": blueprint,
        "blueprint_path": blueprint_path,
        "messages": nav_response.get("messages", [])
    }

# ==========================================
# 3. Coder 노드
# ==========================================
async def coder_node(state: PipelineState) -> dict:
    """Coder 에이전트를 실행하여 크롤링 코드 생성 및 실행"""
    print(f"💻 Coder 시작: {state['user_goal']}")
    print(f"📋 Blueprint 경로: {state['blueprint_path']}")
    
    coder_config = {"configurable": {"thread_id": "coder_pipeline"}}
    coder_context = CoderContext(
        artifact_dir=ARTIFACT_DIR,
        blueprint_path=state["blueprint_path"],
    )
    
    # Coder 실행
    coder_response = await coder_agent.ainvoke(
        {"messages": [HumanMessage(
            f"아래 Blueprint를 기반으로 '{state['user_goal']}' 크롤링 코드를 작성하고 직접 실행해주세요.\n\n"
            f"[Blueprint]\n"
            f"{json.dumps(state['blueprint'], ensure_ascii=False, indent=2)}\n\n"
            f"결과는 artifact_dir에 'pipeline_scraping_result.json'으로 저장하세요."
        )]},
        config=coder_config,
        context=coder_context,
    )
    
    print(f"✅ Coder 완료!")
    
    return {
        "messages": coder_response.get("messages", [])
    }

# ==========================================
# 4. 파이프라인 Graph 구성
# ==========================================
pipeline_graph = StateGraph(PipelineState)

# 노드 추가
pipeline_graph.add_node("navigator", navigator_node)
pipeline_graph.add_node("coder", coder_node)

# 엣지 추가 (흐름 정의)
pipeline_graph.add_edge(START, "navigator")      # START → Navigator
pipeline_graph.add_edge("navigator", "coder")    # Navigator → Coder
pipeline_graph.add_edge("coder", END)            # Coder → END

# 그래프 컴파일
pipeline = pipeline_graph.compile()

print("✅ Pipeline Graph 생성 완료!")
print("\n📊 파이프라인 구조:")
print("[START] → [Navigator] → [Coder] → [END]")

# ==========================================
# 5. 파이프라인 실행 (코드 예시 - 실행하지 않음)
# ==========================================
# 아래 코드는 실제 실행할 때 사용합니다:
"""
# 실행 예시:
result = await pipeline.ainvoke({
    "user_goal": "정치 섹션의 최신 기사 제목과 URL 5개 수집",
    "url": "https://news.naver.com/main.naver",
    "blueprint": {},
    "blueprint_path": "",
    "messages": []
})

print("✅ 파이프라인 완료!")
print(f"최종 결과: {result}")
"""
# Out:
# ✅ Pipeline Graph 생성 완료!
#
# 📊 파이프라인 구조:
# [START] → [Navigator] → [Coder] → [END]
# '\n# 실행 예시:\nresult = await pipeline.ainvoke({\n    "user_goal": "정치 섹션의 최신 기사 제목과 URL 5개 수집",\n    "url": "https://news.naver.com/main.naver",\n    "blueprint": {},\n    "blueprint_path": "",\n    "messages": []\n})\n\nprint("✅ 파이프라인 완료!")\nprint(f"최종 결과: {result}")\n'
